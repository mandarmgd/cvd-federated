# %%
# %run datasets/add_class.py
# Out:
# Cluster centers distances to diseased centroid: [1.3726775894383973, 2.8734179683486443]
# Cluster 0 will be marked as at-risk.
# NEW_DEATH_EVENT
# 0    104
# 2     99
# 1     96
# Name: count, dtype: int64

# %%
# %run client1_image.py

# %%
# %run client2_numerical.py

# %%
# %run Additional/audio.py
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\Desktop\Capstone\CVD Federated Learning\Additional\audio.py:10
#       7 set_a_path = os.path.join(heartbeat_dir, 'set_a.csv')
#       8 set_b_path = os.path.join(heartbeat_dir, 'set_b.csv')
# ---> 10 df_a = pd.read_csv(set_a_path)
#      11 df_b = pd.read_csv(set_b_path)
#      13 df_combined = pd.concat([df_a, df_b], ignore_index=True)
#
# ...

# %%
# %run federated_server.py
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 12s 381ms/step
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 936ms/step
# Cleaning input features...
# 🔍 Cleaning image data for InfFS...
# ✅ Removed near-zero variance features. Remaining: 1611
# 🔍 NaNs: 0, Infs: 0
# 🚀 Applying Infinite Feature Selection...
# 2 Building the graph G = <V,E>
#
# 3 Letting paths tend to infinite
#
# 4 Estimating energy scores
#
# 5) Features ranking
#      Unnamed: 0       age   anaemia  creatinine_phosphokinase  diabetes  \
# 0     -1.726268  1.192945 -0.871105                  0.000166 -0.847579
# 1     -1.714682 -0.491279 -0.871105                  7.514640 -0.847579
# 2     -1.703096  0.350833 -0.871105                 -0.449939 -0.847579
# 3     -1.691511 -0.912335  1.147968                 -0.486071 -0.847579
# 4     -1.679925  0.350833  1.147968                 -0.435486  1.179830
# ..          ...       ...       ...                       ...       ...
# 294    1.679925  0.098199 -0.871105                 -0.537688  1.179830
# ...
